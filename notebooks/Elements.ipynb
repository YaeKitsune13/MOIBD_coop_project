# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #6e8efb, #a777e3);
#     padding: 30px;
#     border-radius: 15px;
#     box-shadow: 0 4px 15px rgba(0,0,0,0.2);
#     text-align: center;
#     color: white;
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <h1 style="margin: 0; font-size: 40px; border: none; color: white;">🚀 Основной заголовок проекта</h1>
#     <p style="margin: 10px 0 0; font-size: 18px; opacity: 0.9;">Анализ данных и машинное обучение</p>
# </div>

# %% [markdown]
# <div style="
#     background-color: #f8f9fa;
#     border-left: 8px solid #6e8efb;
#     padding: 15px;
#     border-radius: 5px;
#     font-family: sans-serif;">
#     <details>
#         <summary style="font-weight: bold; font-size: 20px; cursor: pointer;">📍 Содержание (нажми, чтобы развернуть)</summary>
#         <ul style="margin-top: 10px; line-height: 1.8;">
#             <li><a href="#1" style="color: #6e8efb; text-decoration: none; font-weight: bold;">1. Загрузка данных</a></li>
#             <li><a href="#2" style="color: #6e8efb; text-decoration: none; font-weight: bold;">2. Предобработка и очистка</a></li>
#             <li><a href="#3" style="color: #6e8efb; text-decoration: none; font-weight: bold;">3. Обучение модели</a></li>
#             <li><a href="#4" style="color: #6e8efb; text-decoration: none; font-weight: bold;">4. Выводы</a></li>
#         </ul>
#     </details>
# </div>

# %% [markdown]
# <div style="padding: 15px; border-radius: 10px; background-color: #e3f2fd; border-left: 6px solid #2196f3; color: #0d47a1;">
#     <strong>ℹ️ Описание:</strong> В данном разделе мы проводим анализ корреляций между признаками, чтобы исключить мультиколлинеарность.
# </div>

# %% [markdown]
# <div style="padding: 15px; border-radius: 10px; background-color: #fff3e0; border-left: 6px solid #ff9800; color: #e65100;">
#     <strong>⚠️ Важно:</strong> Перед запуском этой ячейки убедитесь, что в папке <code>/data</code> лежит файл <code>dataset.csv</code>.
# </div>

# %% [markdown]
# <div style="display: flex; gap: 10px; margin-top: 20px; color:#fff">
#     <div style="flex: 1; padding: 10px; background: #aaa; border-radius: 5px; text-align: center;">
#         <strong>Сбор данных</strong>
#     </div>
#     <div style="flex: 1; padding: 10px; background: #aaa; border-radius: 5px; text-align: center;">
#         <strong>Очистка</strong>
#     </div>
#     <div style="flex: 1; padding: 10px; background: #aaa; border-radius: 5px; text-align: center;">
#         <strong>ML Модель</strong>
#     </div>
# </div>

# %% [markdown]
# <div style="
#     padding: 20px;
#     background-color: #e8f5e9;
#     border: 2px dashed #4caf50;
#     border-radius: 15px;
#     color: #1b5e20;
#     font-size: 16px;">
#     <h3 style="margin-top: 0; color: #2e7d32;">✅ Итоги:</h3>
#     <ul>
#         <li>Модель достигла точности <b>94.5%</b>.</li>
#         <li>Самый важный фактор — уровень дохода клиента.</li>
#         <li>Рекомендовано использовать <b>RandomForest</b> для продакшена.</li>
#     </ul>
# </div>
